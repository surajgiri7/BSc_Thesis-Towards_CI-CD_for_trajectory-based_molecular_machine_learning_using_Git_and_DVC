# %% [markdown]
# # Jupyter Notebook to showcase the features of Data Version Control (DVC)
# ### Thesis topic: **"Towards CI/CD for trajectory-based molecular machine learning using Git and DVC"**
# #### Author: Suraj Giri
# #### Supervisor: Prof. Dr. Peter Zaspel
# ### **Preliminary Dataset** : 10k .xyz files with molecular trajectories of C6H6 molecules and a .dat file with energies for those 10k molecules.
#
# #### Major Tasks:
# 1. Developing **Kernel Ridge Regression in DVC Structure**
# 2. Developing **Testing Software in DVC Structure**
# 3. Jupyter Notebooks to showcase features of DVC for ML

# %% [markdown]
# Firstly, we developed a Kernel Ridge Regression model using QML: A Python toolkit for Quantum machine learning. The KRR model was developed in a modularized way with three stages: **prepare, train, and test**. This jupyter notebook is dedicated in showcasing the features of DVC.

# %% [markdown]
# Installing dvc

# %%
! pip install dvc
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dvc
#   Using cached dvc-0.78.1-py2.py3-none-any.whl (296 kB)
# Collecting python-dateutil<2.8.1,>=2.1
#   Using cached python_dateutil-2.8.0-py2.py3-none-any.whl (226 kB)
# Collecting gitpython>=2.1.8
#   Using cached GitPython-2.1.15-py2.py3-none-any.whl (452 kB)
# Collecting inflect<4,>=2.1.0
#   Using cached inflect-3.0.2-py2.py3-none-any.whl (31 kB)
# Collecting voluptuous>=0.11.7
#   Using cached voluptuous-0.13.1.tar.gz (47 kB)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-0.5.0.tar.gz (6.1 kB)
# Collecting zc.lockfile>=1.2.1
#   Using cached zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting nanotime>=0.5.2
#   Using cached nanotime-0.5.2.tar.gz (3.2 kB)
# Collecting pathspec>=0.6.0
#   Using cached pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting configobj>=5.0.6
#   Using cached configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Collecting pyasn1>=0.4.1
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting appdirs>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting configparser>=3.5.0
#   Using cached configparser-4.0.2-py2.py3-none-any.whl (22 kB)
# Collecting ply>=3.9
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting gitdb2>=2.0.6
#   Using cached gitdb2-4.0.2.tar.gz (949 bytes)
# Collecting tqdm<5,>=4.40.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting networkx<2.4,>=2.1
#   Using cached networkx-2.2.zip (1.7 MB)
# Collecting PyYAML<5.2,>=5.1.2
#   Using cached PyYAML-5.1.2.tar.gz (265 kB)
# Collecting distro>=1.3.0
#   Using cached distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting colorama>=0.3.9
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting packaging>=19.0
#   Using cached packaging-20.9-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/lib/python2.7/dist-packages (from dvc) (39.0.1)
# Collecting humanize>=0.5.1
#   Using cached humanize-1.0.0-py2.py3-none-any.whl (51 kB)
# Collecting requests>=2.22.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting funcy>=1.14
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting jsonpath-ng>=1.4.3
#   Using cached jsonpath_ng-1.5.3-py2-none-any.whl (29 kB)
# Collecting futures; python_version == "2.7"
#   Using cached futures-3.4.0-py2-none-any.whl (16 kB)
# Collecting contextlib2; python_version == "2.7"
#   Using cached contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting treelib>=1.5.5
#   Using cached treelib-1.6.4.tar.gz (25 kB)
# Collecting ruamel.yaml>=0.16.1
#   Using cached ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting future>=0.16.0
#   Using cached future-0.18.3.tar.gz (840 kB)
# Collecting pathlib2; python_version == "2.7"
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting grandalf==0.6
#   Using cached grandalf-0.6-py2-none-any.whl (31 kB)
# Requirement already satisfied: six>=1.5 in /home/sgiri/.local/lib/python2.7/site-packages (from python-dateutil<2.8.1,>=2.1->dvc) (1.16.0)
# Collecting importlib-metadata
#   Using cached importlib_metadata-2.1.3-py2.py3-none-any.whl (10 kB)
# ERROR: Could not find a version that satisfies the requirement gitdb>=4.0.1 (from gitdb2>=2.0.6->dvc) (from versions: 0.5.0, 0.5.1, 0.5.2, 0.5.3, 0.5.4, 0.6.0, 0.6.1, 0.6.2, 0.6.3, 0.6.4)
# ERROR: No matching distribution found for gitdb>=4.0.1 (from gitdb2>=2.0.6->dvc)

# %% [markdown]
# Pulling the Dataset from remote storage

# %%
! dvc pull
# Out:
#   0% Checkout|                                   |0/10008 [00:00<?,     ?file/s]
# !
# Building data objects from output/test/actual_pred    |0.00 [00:00,      ?obj/s]
#
# !
# Building data objects from dataset                    |0.00 [00:00,      ?obj/s]
# Building data objects from dataset                   |1.42k [00:00,  14.2kobj/s]
# Building data objects from dataset                   |2.83k [00:00,  13.6kobj/s]
# Building data objects from dataset                   |4.92k [00:00,  16.8kobj/s]
# Building data objects from dataset                   |7.03k [00:00,  18.5kobj/s]
# Building data objects from dataset                   |9.21k [00:00,  19.7kobj/s]
# Everything is up to date.

# %%
! git checkout v6.0
! dvc checkout
# Out:
# M	dvc_plots/index.html
# M	dvc_plots/static/workspace_output_plots_Learning_Curve.png
# M	output/metrics.csv
# M	output/test/live/metrics.json
# M	params.yaml
# HEAD is now at f2969dd Model with dvc plots show and dvc exp run
#   0% Checkout|                                   |0/10008 [00:00<?,     ?file/s]
# !
# Building data objects from output/test/actual_pred    |0.00 [00:00,      ?obj/s]
#
# !
# Building data objects from dataset                    |0.00 [00:00,      ?obj/s]
# Building data objects from dataset                     |837 [00:00,  8.37kobj/s]
# Building data objects from dataset                   |2.56k [00:00,  13.6kobj/s]
# Building data objects from dataset                   |3.91k [00:00,  13.4kobj/s]
# Building data objects from dataset                   |5.99k [00:00,  16.3kobj/s]
# Building data objects from dataset                   |8.11k [00:00,  18.0kobj/s]

# %% [markdown]
# Reproducing the whole DVC Pipeline using **dvc repro**

# %%
! dvc repro
# Out:
# 'dataset.dvc' didn't change, skipping
# Stage 'prepare' didn't change, skipping
# Stage 'test' didn't change, skipping
# Stage 'train' didn't change, skipping
# Data and pipelines are up to date.

# %% [markdown]
# Visualization of the DVC Pipeline

# %%
! dvc dag
# Out:
#         +-------------+
#         | dataset.dvc |
#         +-------------+
#           **        **
#         **            **
#        *                **
# +---------+               *
# | prepare |             **
# +---------+           **
#           **        **
#             **    **
#               *  *
#            +-------+
#            | train |
#            +-------+
# +------+
# | test |
# +------+

# %% [markdown]
# ## Experiment Management

# %% [markdown]
# Running the dvc experiment using **dvc exp run**

# %%
! dvc exp run
# Out:
#   0% Checkout|                                   |0/10008 [00:00<?,     ?file/s]
# !
# Building data objects from output/test/actual_pred    |0.00 [00:00,      ?obj/s]
#
# !
# Building data objects from dataset                    |0.00 [00:00,      ?obj/s]
# Building data objects from dataset                     |500 [00:00,  5.00kobj/s]
# Building data objects from dataset                   |1.78k [00:00,  9.56kobj/s]
# Building data objects from dataset                   |3.04k [00:00,  11.0kobj/s]
# Building data objects from dataset                   |4.31k [00:00,  11.6kobj/s]
# Building data objects from dataset                   |5.59k [00:00,  12.1kobj/s]
# Building data objects from dataset                   |6.85k [00:00,  12.2kobj/s]
# Building data objects from dataset                   |8.12k [00:00,  12.4kobj/s]
# Building data objects from dataset                   |9.40k [00:00,  12.5kobj/s]
# 'dataset.dvc' didn't change, skipping
# Stage 'prepare' didn't change, skipping
# Stage 'test' didn't change, skipping
# Stage 'train' didn't change, skipping
#                                                                       core>
# Ran experiment(s): sonic-hows
# Experiment results have been applied to your workspace.
#
# To promote an experiment to a Git branch run:
#
# 	dvc exp branch <exp> <branch>

# %% [markdown]
# Showing and comparing the results of different experiments

# %%
! dvc exp show
# Out:
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Experiment                 Created        errors.MAE   errors.MSE   errors.RMSE   errors.COD   train.sigma   train.order   train.metric   dataset   output/dataset   output/prepared_data.pkl   src/prepare.py   src/test.py   src/train.py
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   workspace                  -              9.9766e-14   1.5647e-26    1.2509e-13            1   60            0             l2             2ed55dd   4cb699d          af8572d                    51f3c58          43ac3ad       6557734
#   v6.0                       Apr 09, 2023   5.0334e-15   4.0176e-29    6.3385e-15            1   25            0             l1             2ed55dd   1da5b2e          af8572d                    51f3c58          43ac3ad       6557734
#   ├── d5cb130 [sonic-hows]   06:53 PM       9.9766e-14   1.5647e-26    1.2509e-13            1   60            0             l2             2ed55dd   4cb699d          af8572d                    51f3c58          43ac3ad       6557734
#   └── 9b276b9 [moved-kago]   Apr 09, 2023   5.0334e-15   4.0176e-29    6.3385e-15            1   25            0             l1             2ed55dd   1da5b2e          af8572d                    51f3c58          43ac3ad       6557734
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Displaying the parameters of the experiment

# %%
! dvc metrics show
# Out:
# Path                           errors.COD    errors.MAE    errors.MSE    errors.RMSE
# output/metrics.csv             -             -             -             -
# output/test/live/metrics.json  1.0           0.0           0.0           0.0

# %% [markdown]
# Displaying the Difference in metrics

# %%
! dvc metrics diff
# Out:
# Path                           Metric       HEAD    workspace    Changeore>
# output/test/live/metrics.json  errors.MAE   0.0     0.0          0.0
# output/test/live/metrics.json  errors.MSE   0.0     0.0          0.0
# output/test/live/metrics.json  errors.RMSE  0.0     0.0          0.0

# %% [markdown]
# Displaying the plots using dvc plots show

# %%
from IPython.display import HTML, display, IFrame

! dvc plots show

display(HTML(filename="/home/sgiri/BSc_Thesis_DVC/dvc_plots/index.html"))
IFrame(src='/home/sgiri/BSc_Thesis_DVC/dvc_plots/index.html', width=700, height=500)
# Out:
# file:///home/sgiri/BSc_Thesis_DVC/dvc_plots/index.html
# <!DOCTYPE html>
# <html>
# <head>
#
#     <title>DVC Plot</title>
#
#
#     <script src="https://cdn.jsdelivr.net/npm/vega@5.20.2"></script>
#     <script src="https://cdn.jsdelivr.net/npm/vega-lite@5.2.0"></script>
#     <script src="https://cdn.jsdelivr.net/npm/vega-embed@6.18.2"></script>
#
#     <style>
#         table {
#             border-spacing: 15px;
#         }
#     </style>
# </head>
# <body>
#
#     <div id = "dvc_yaml__APTrain">
#         <script type = "text/javascript">
#             var spec = {"$schema": "https://vega.github.io/schema/vega-lite/v5.json", "data": {"values": [{"molecule": "1", "actual": "5.518798", "predicted": "5.518797999999978", "rev": "workspace"}, {"molecule": "2", "actual": "5.521764", "predicted": "5.52176400000015", "rev": "workspace"}, {"molecule": "3", "actual": "5.524758", "predicted": "5.524758000000143", "rev": "workspace"}, {"molecule": "4", "actual": "5.527805", "predicted": "5.527804999999922", "rev": "workspace"}, {"molecule": "5", "actual": "5.530717", "predicted": "5.530717000000073", "rev": "workspace"}, {"molecule": "6", "actual": "5.533574", "predicted": "5.533573999999906